# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, input_size))
            feed_actor = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            self.logits = tf.layers.dense(feed_actor, output_size)

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            self.REWARD = tf.placeholder(tf.float32, (None, 1))
            feed_critic = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            feed_critic = tf.layers.dense(feed_critic, output_size, activation = tf.nn.relu) + self.Y
            feed_critic = tf.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(tf.square(self.REWARD - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate).minimize(self.cost)
            
class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE, 
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(self.critic.logits, self.critic.Y)
        self.actor_critic_grad = tf.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(self.actor.logits, weights_actor, -self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)
            
    def _memorize(self, state, action, reward, new_state, dead):
        self.MEMORIES.append((state, action, reward, new_state, dead))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action
    
    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads})
        
        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits, 
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target})
        for i in range(len(replay)):
            if not replay[0][-1]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer], 
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards})
        return cost
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# epoch: 10, total rewards: 577.884884.3, cost: 0.118294, total money: 6592.614864
# epoch: 20, total rewards: 1999.570005.3, cost: 0.105594, total money: 6126.639951
# epoch: 30, total rewards: 75.114745.3, cost: 0.338154, total money: 5129.044738
# epoch: 40, total rewards: 269.524543.3, cost: 0.093277, total money: 6336.644537
# epoch: 50, total rewards: 1245.309941.3, cost: 0.068934, total money: 10272.749943
# epoch: 60, total rewards: 429.375178.3, cost: 0.081137, total money: 4679.735163
# epoch: 70, total rewards: 545.365235.3, cost: 0.092208, total money: 3861.915284
# epoch: 80, total rewards: 1316.115172.3, cost: 0.066458, total money: 3662.105162
# epoch: 90, total rewards: 1316.304866.3, cost: 0.143081, total money: 8356.564875
# epoch: 100, total rewards: 1219.624933.3, cost: 0.135950, total money: 11219.624933
# epoch: 110, total rewards: 332.694827.3, cost: 0.078676, total money: 649.574832
# epoch: 120, total rewards: 350.540041.3, cost: 0.044347, total money: 5409.920045
# epoch: 130, total rewards: 1459.155090.3, cost: 0.059339, total money: 5656.205078
# epoch: 140, total rewards: 809.060056.3, cost: 0.177413, total money: 9789.790036
# epoch: 150, total rewards: 246.495055.3, cost: 0.519768, total money: 1724.454955
# epoch: 160, total rewards: 824.310608.3, cost: 0.073918, total money: 10824.310608
# epoch: 170, total rewards: 691.220156.3, cost: 0.056950, total money: 8736.230166
# epoch: 180, total rewards: 383.774780.3, cost: 0.038410, total money: 9366.664795
# epoch: 190, total rewards: 1988.899842.3, cost: 0.090984, total money: 6321.579774
# epoch: 200, total rewards: 960.260132.3, cost: 0.100058, total money: 2563.730103

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 768.700012, total balance 9231.299988
# day 3, sell 1 unit at price 782.520020, investment 1.797842 %, total balance 10013.820008,
# day 6: buy 1 unit at price 762.559998, total balance 9251.260010
# day 8: buy 1 unit at price 736.080017, total balance 8515.179993
# day 9, sell 1 unit at price 758.489990, investment -0.533730 %, total balance 9273.669983,
# day 11: buy 1 unit at price 771.229980, total balance 8502.440003
# day 12: buy 1 unit at price 760.539978, total balance 7741.900025
# day 13: buy 1 unit at price 769.200012, total balance 6972.700013
# day 14: buy 1 unit at price 768.270020, total balance 6204.429993
# day 18, sell 1 unit at price 770.840027, investment 4.722314 %, total balance 6975.270020,
# day 19, sell 1 unit at price 758.039978, investment -1.710255 %, total balance 7733.309998,
# day 20: buy 1 unit at price 747.919983, total balance 6985.390015
# day 25: buy 1 unit at price 776.419983, total balance 6208.970032
# day 26, sell 1 unit at price 789.289978, investment 3.780209 %, total balance 6998.260010,
# day 29, sell 1 unit at price 797.070007, investment 3.623244 %, total balance 7795.330017,
# day 31: buy 1 unit at price 790.799988, total balance 7004.530029
# day 33: buy 1 unit at price 796.419983, total balance 6208.110046
# day 34: buy 1 unit at price 794.559998, total balance 5413.550048
# day 35: buy 1 unit at price 791.260010, total balance 4622.290038
# day 38, sell 1 unit at price 785.049988, investment 2.184124 %, total balance 5407.340026,
# day 40: buy 1 unit at price 771.820007, total balance 4635.520019
# day 42, sell 1 unit at price 786.900024, investment 5.211793 %, total balance 5422.420043,
# day 43, sell 1 unit at price 794.020020, investment 2.266819 %, total balance 6216.440063,
# day 44, sell 1 unit at price 806.150024, investment 1.941077 %, total balance 7022.590087,
# day 45, sell 1 unit at price 806.650024, investment 1.284503 %, total balance 7829.240111,
# day 46: buy 1 unit at price 804.789978, total balance 7024.450133
# day 47: buy 1 unit at price 807.909973, total balance 6216.540160
# day 48: buy 1 unit at price 806.359985, total balance 5410.180175
# day 49: buy 1 unit at price 807.880005, total balance 4602.300170
# day 52: buy 1 unit at price 802.174988, total balance 3800.125182
# day 54: buy 1 unit at price 819.309998, total balance 2980.815184
# day 55, sell 1 unit at price 823.869995, investment 3.688834 %, total balance 3804.685179,
# day 56, sell 1 unit at price 835.669983, investment 5.612564 %, total balance 4640.355162,
# day 57: buy 1 unit at price 832.150024, total balance 3808.205138
# day 59: buy 1 unit at price 802.320007, total balance 3005.885131
# day 60, sell 1 unit at price 796.789978, investment 3.235206 %, total balance 3802.675109,
# day 61: buy 1 unit at price 795.695007, total balance 3006.980102
# day 62, sell 1 unit at price 798.530029, investment -0.777836 %, total balance 3805.510131,
# day 64: buy 1 unit at price 801.340027, total balance 3004.170104
# day 65: buy 1 unit at price 806.969971, total balance 2197.200133
# day 66: buy 1 unit at price 808.380005, total balance 1388.820128
# day 69: buy 1 unit at price 819.239990, total balance 569.580138
# day 70, sell 1 unit at price 820.450012, investment 1.552158 %, total balance 1390.030150,
# day 75, sell 1 unit at price 830.760010, investment 3.025947 %, total balance 2220.790160,
# day 77: buy 1 unit at price 828.640015, total balance 1392.150145
# day 78: buy 1 unit at price 829.280029, total balance 562.870116
# day 81, sell 1 unit at price 830.630005, investment 2.816012 %, total balance 1393.500121,
# day 83: buy 1 unit at price 827.780029, total balance 565.720092
# day 85, sell 1 unit at price 835.369995, investment 4.138125 %, total balance 1401.090087,
# day 86, sell 1 unit at price 838.679993, investment 2.364184 %, total balance 2239.770080,
# day 87: buy 1 unit at price 843.250000, total balance 1396.520080
# day 88: buy 1 unit at price 845.539978, total balance 550.980102
# day 89, sell 1 unit at price 845.619995, investment 1.618695 %, total balance 1396.600097,
# day 90: buy 1 unit at price 847.200012, total balance 549.400085
# day 92, sell 1 unit at price 852.119995, investment 6.206998 %, total balance 1401.520080,
# day 93: buy 1 unit at price 848.400024, total balance 553.120056
# day 99, sell 1 unit at price 820.919983, investment 3.170182 %, total balance 1374.040039,
# day 100: buy 1 unit at price 831.409973, total balance 542.630066
# day 101, sell 1 unit at price 831.500000, investment 3.763692 %, total balance 1374.130066,
# day 103, sell 1 unit at price 838.549988, investment 3.913407 %, total balance 2212.680054,
# day 104, sell 1 unit at price 834.570007, investment 3.239813 %, total balance 3047.250061,
# day 110: buy 1 unit at price 824.320007, total balance 2222.930054
# day 111: buy 1 unit at price 823.559998, total balance 1399.370056
# day 112: buy 1 unit at price 837.169983, total balance 562.200073
# day 113, sell 1 unit at price 836.820007, investment 2.145893 %, total balance 1399.020080,
# day 115, sell 1 unit at price 841.650024, investment 1.570044 %, total balance 2240.670104,
# day 116, sell 1 unit at price 843.190002, investment 1.677355 %, total balance 3083.860106,
# day 118, sell 1 unit at price 872.299988, investment 5.378235 %, total balance 3956.160094,
# day 119, sell 1 unit at price 871.729980, investment 3.377406 %, total balance 4827.890074,
# day 120: buy 1 unit at price 874.250000, total balance 3953.640074
# day 122: buy 1 unit at price 912.570007, total balance 3041.070067
# day 123, sell 1 unit at price 916.440002, investment 8.385177 %, total balance 3957.510069,
# day 125, sell 1 unit at price 931.659973, investment 9.969306 %, total balance 4889.170042,
# day 128, sell 1 unit at price 932.169983, investment 9.873875 %, total balance 5821.340025,
# day 130: buy 1 unit at price 930.599976, total balance 4890.740049
# day 132, sell 1 unit at price 937.080017, investment 12.709740 %, total balance 5827.820066,
# day 133, sell 1 unit at price 943.000000, investment 14.397320 %, total balance 6770.820066,
# day 134, sell 1 unit at price 919.619995, investment 11.663995 %, total balance 7690.440061,
# day 136: buy 1 unit at price 934.010010, total balance 6756.430051
# day 137, sell 1 unit at price 941.859985, investment 12.505226 %, total balance 7698.290036,
# day 138: buy 1 unit at price 948.820007, total balance 6749.470029
# day 139, sell 1 unit at price 954.960022, investment 9.231916 %, total balance 7704.430051,
# day 140, sell 1 unit at price 969.539978, investment 6.242806 %, total balance 8673.970029,
# day 141, sell 1 unit at price 971.469971, investment 4.391790 %, total balance 9645.440000,
# day 142, sell 1 unit at price 975.880005, investment 4.482821 %, total balance 10621.320005,
# day 146: buy 1 unit at price 983.679993, total balance 9637.640012
# day 148: buy 1 unit at price 980.940002, total balance 8656.700010
# day 149, sell 1 unit at price 983.409973, investment 3.645577 %, total balance 9640.109983,
# day 151: buy 1 unit at price 942.900024, total balance 8697.209959
# day 152: buy 1 unit at price 953.400024, total balance 7743.809935
# day 153: buy 1 unit at price 950.760010, total balance 6793.049925
# day 156, sell 1 unit at price 957.369995, investment -2.674650 %, total balance 7750.419920,
# day 157: buy 1 unit at price 950.630005, total balance 6799.789915
# day 158: buy 1 unit at price 959.450012, total balance 5840.339903
# day 159: buy 1 unit at price 957.090027, total balance 4883.249876
# day 160: buy 1 unit at price 965.590027, total balance 3917.659849
# day 161, sell 1 unit at price 952.270020, investment -2.922705 %, total balance 4869.929869,
# day 164: buy 1 unit at price 917.789978, total balance 3952.139891
# day 165: buy 1 unit at price 908.729980, total balance 3043.409911
# day 166, sell 1 unit at price 898.700012, investment -4.687667 %, total balance 3942.109923,
# day 168, sell 1 unit at price 906.690002, investment -4.899310 %, total balance 4848.799925,
# day 169: buy 1 unit at price 918.590027, total balance 3930.209898
# day 176, sell 1 unit at price 965.400024, investment 1.539822 %, total balance 4895.609922,
# day 177, sell 1 unit at price 970.890015, investment 2.131219 %, total balance 5866.499937,
# day 178, sell 1 unit at price 968.150024, investment 0.906771 %, total balance 6834.649961,
# day 179, sell 1 unit at price 972.919983, investment 1.653967 %, total balance 7807.569944,
# day 180: buy 1 unit at price 980.340027, total balance 6827.229917
# day 181: buy 1 unit at price 950.700012, total balance 5876.529905
# day 182: buy 1 unit at price 947.799988, total balance 4928.729917
# day 183: buy 1 unit at price 934.090027, total balance 3994.639890
# day 185: buy 1 unit at price 930.500000, total balance 3064.139890
# day 186: buy 1 unit at price 930.830017, total balance 2133.309873
# day 187, sell 1 unit at price 930.390015, investment -3.645441 %, total balance 3063.699888,
# day 188, sell 1 unit at price 923.650024, investment 0.638495 %, total balance 3987.349912,
# day 189: buy 1 unit at price 927.960022, total balance 3059.389890
# day 190, sell 1 unit at price 929.359985, investment 2.270202 %, total balance 3988.749875,
# day 191, sell 1 unit at price 926.789978, investment 0.892667 %, total balance 4915.539853,
# day 192: buy 1 unit at price 922.900024, total balance 3992.639829
# day 194, sell 1 unit at price 914.390015, investment -6.727259 %, total balance 4907.029844,
# day 195: buy 1 unit at price 922.669983, total balance 3984.359861
# day 197: buy 1 unit at price 926.960022, total balance 3057.399839
# day 200, sell 1 unit at price 906.659973, investment -4.632380 %, total balance 3964.059812,
# day 204: buy 1 unit at price 915.890015, total balance 3048.169797
# day 205: buy 1 unit at price 913.809998, total balance 2134.359799
# day 207, sell 1 unit at price 929.570007, investment -1.923400 %, total balance 3063.929806,
# day 208: buy 1 unit at price 939.330017, total balance 2124.599789
# day 209: buy 1 unit at price 937.340027, total balance 1187.259762
# day 210: buy 1 unit at price 928.450012, total balance 258.809750
# day 213, sell 1 unit at price 926.500000, investment -0.812558 %, total balance 1185.309750,
# day 214: buy 1 unit at price 929.080017, total balance 256.229733
# day 217, sell 1 unit at price 925.109985, investment -0.579260 %, total balance 1181.339718,
# day 219, sell 1 unit at price 915.000000, investment -1.700635 %, total balance 2096.339718,
# day 222: buy 1 unit at price 932.450012, total balance 1163.889706
# day 224: buy 1 unit at price 920.969971, total balance 242.919735
# day 226, sell 1 unit at price 944.489990, investment 1.781323 %, total balance 1187.409725,
# day 227: buy 1 unit at price 949.500000, total balance 237.909725
# day 229, sell 1 unit at price 953.270020, investment 3.290714 %, total balance 1191.179745,
# day 231: buy 1 unit at price 951.679993, total balance 239.499752
# day 233, sell 1 unit at price 978.890015, investment 6.093190 %, total balance 1218.389767,
# day 236, sell 1 unit at price 989.250000, investment 6.719813 %, total balance 2207.639767,
# day 237: buy 1 unit at price 987.830017, total balance 1219.809750
# day 239, sell 1 unit at price 992.000000, investment 8.309948 %, total balance 2211.809750,
# day 241, sell 1 unit at price 992.809998, investment 8.645123 %, total balance 3204.619748,
# day 242, sell 1 unit at price 984.450012, investment 4.803423 %, total balance 4189.069760,
# day 244: buy 1 unit at price 968.450012, total balance 3220.619748
# day 246: buy 1 unit at price 973.330017, total balance 2247.289731
# day 248: buy 1 unit at price 1019.270020, total balance 1228.019711
# day 249, sell 1 unit at price 1017.109985, investment 8.510248 %, total balance 2245.129696,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
