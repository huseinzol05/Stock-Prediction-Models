# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate, name):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            cell = tf.nn.rnn_cell.LSTMCell(layer_size, state_is_tuple = False)
            self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * layer_size))
            self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            tensor_action, tensor_validation = tf.split(self.rnn[:,-1],2,1)
            feed_action = tf.layers.dense(tensor_action, output_size)
            feed_validation = tf.layers.dense(tensor_validation, 1)
            self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
            self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 1
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE,
                           'real_model')
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE,
                                   'negative_model')
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.model.logits, feed_dict={self.model.X:states, 
                                                   self.model.hidden_layer:init_values})
        Q_new = self.sess.run(self.model.logits, feed_dict={self.model.X:new_states, 
                                                       self.model.hidden_layer:init_values})
        Q_new_negative = self.sess.run(self.model_negative.logits, 
                                  feed_dict={self.model_negative.X:new_states, 
                                             self.model_negative.hidden_layer:init_values})
        replay_size = len(replay)
        X = np.empty((replay_size, 4, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        INIT_VAL = np.empty((replay_size, 2 * self.LAYER_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, dead_r, rnn_memory = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not dead_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
            INIT_VAL[i] = rnn_memory
        return X, Y, INIT_VAL
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            action, last_state = self.sess.run([self.model.logits,self.model.last_state],
                                                feed_dict={self.model.X:[self.INITIAL_FEATURES],
                                                            self.model.hidden_layer:init_value})
            action, init_value = np.argmax(action[0]), last_state
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('real_model', 'negative_model')
                
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.model.logits,
                                                  self.model.last_state],
                                                  feed_dict={self.model.X:[self.INITIAL_FEATURES],
                                                             self.model.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                    
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                self.INITIAL_FEATURES = new_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y, INIT_VAL = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y,
                                                  self.model.hidden_layer: INIT_VAL})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fd77616ecc0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:From <ipython-input-3-79d715b7fb13>:17: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fd77616ec50>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# epoch: 10, total rewards: 1605.740115.3, cost: 0.080742, total money: 6764.060122
# epoch: 20, total rewards: 1014.015317.3, cost: 0.297948, total money: 5165.075314
# epoch: 30, total rewards: 358.679684.3, cost: 0.815488, total money: 765.989742
# epoch: 40, total rewards: 1264.344849.3, cost: 0.655021, total money: 5388.384827
# epoch: 50, total rewards: 1258.475037.3, cost: 0.222286, total money: 2504.745056
# epoch: 60, total rewards: 1016.684756.3, cost: 0.148369, total money: 8065.474734
# epoch: 70, total rewards: 244.774965.3, cost: 0.885347, total money: 1434.554932
# epoch: 80, total rewards: 92.799984.3, cost: 0.339370, total money: 10092.799984
# epoch: 90, total rewards: 1078.379824.3, cost: 0.618235, total money: 4298.999818
# epoch: 100, total rewards: 535.134828.3, cost: 0.375909, total money: 6608.234803
# epoch: 110, total rewards: 715.345089.3, cost: 0.951146, total money: 8730.355098
# epoch: 120, total rewards: 755.955264.3, cost: 0.676888, total money: 4945.475283
# epoch: 130, total rewards: 497.115050.3, cost: 0.571670, total money: 8461.205015
# epoch: 140, total rewards: 810.325378.3, cost: 0.123932, total money: 7832.155334
# epoch: 150, total rewards: 1621.924933.3, cost: 0.741764, total money: 7698.964911
# epoch: 160, total rewards: 914.104977.3, cost: 0.381776, total money: 3032.544979
# epoch: 170, total rewards: 927.849856.3, cost: 0.073761, total money: 8894.099856
# epoch: 180, total rewards: 481.245235.3, cost: 0.258569, total money: 3580.105220
# epoch: 190, total rewards: 231.005557.3, cost: 0.123501, total money: 5295.215518
# epoch: 200, total rewards: 369.564817.3, cost: 0.080562, total money: 4398.764767

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 6: buy 1 unit at price 762.559998, total balance 9237.440002
# day 7: buy 1 unit at price 754.020020, total balance 8483.419982
# day 8: buy 1 unit at price 736.080017, total balance 7747.339965
# day 10: buy 1 unit at price 764.479980, total balance 6982.859985
# day 12, sell 1 unit at price 760.539978, investment -0.264900 %, total balance 7743.399963,
# day 15: buy 1 unit at price 760.989990, total balance 6982.409973
# day 16, sell 1 unit at price 761.679993, investment 1.015885 %, total balance 7744.089966,
# day 17, sell 1 unit at price 768.239990, investment 4.369087 %, total balance 8512.329956,
# day 18, sell 1 unit at price 770.840027, investment 0.831944 %, total balance 9283.169983,
# day 19: buy 1 unit at price 758.039978, total balance 8525.130005
# day 21, sell 1 unit at price 750.500000, investment -1.378466 %, total balance 9275.630005,
# day 23, sell 1 unit at price 759.109985, investment 0.141154 %, total balance 10034.739990,
# day 28: buy 1 unit at price 796.099976, total balance 9238.640014
# day 29, sell 1 unit at price 797.070007, investment 0.121848 %, total balance 10035.710021,
# day 32: buy 1 unit at price 794.200012, total balance 9241.510009
# day 33, sell 1 unit at price 796.419983, investment 0.279523 %, total balance 10037.929992,
# day 34: buy 1 unit at price 794.559998, total balance 9243.369994
# day 36, sell 1 unit at price 789.909973, investment -0.585233 %, total balance 10033.279967,
# day 38: buy 1 unit at price 785.049988, total balance 9248.229979
# day 39, sell 1 unit at price 782.789978, investment -0.287881 %, total balance 10031.019957,
# day 41: buy 1 unit at price 786.140015, total balance 9244.879942
# day 42, sell 1 unit at price 786.900024, investment 0.096676 %, total balance 10031.779966,
# day 48: buy 1 unit at price 806.359985, total balance 9225.419981
# day 49: buy 1 unit at price 807.880005, total balance 8417.539976
# day 50, sell 1 unit at price 804.609985, investment -0.217025 %, total balance 9222.149961,
# day 51: buy 1 unit at price 806.070007, total balance 8416.079954
# day 52: buy 1 unit at price 802.174988, total balance 7613.904966
# day 53, sell 1 unit at price 805.020020, investment -0.354011 %, total balance 8418.924986,
# day 54: buy 1 unit at price 819.309998, total balance 7599.614988
# day 55: buy 1 unit at price 823.869995, total balance 6775.744993
# day 56: buy 1 unit at price 835.669983, total balance 5940.075010
# day 58, sell 1 unit at price 823.309998, investment 2.138771 %, total balance 6763.385008,
# day 59, sell 1 unit at price 802.320007, investment 0.018078 %, total balance 7565.705015,
# day 61, sell 1 unit at price 795.695007, investment -2.882302 %, total balance 8361.400022,
# day 62: buy 1 unit at price 798.530029, total balance 7562.869993
# day 64, sell 1 unit at price 801.340027, investment -2.734651 %, total balance 8364.210020,
# day 65, sell 1 unit at price 806.969971, investment -3.434372 %, total balance 9171.179991,
# day 66: buy 1 unit at price 808.380005, total balance 8362.799986
# day 67, sell 1 unit at price 809.559998, investment 1.381284 %, total balance 9172.359984,
# day 68, sell 1 unit at price 813.669983, investment 0.654392 %, total balance 9986.029967,
# day 70: buy 1 unit at price 820.450012, total balance 9165.579955
# day 71, sell 1 unit at price 818.979980, investment -0.179174 %, total balance 9984.559935,
# day 76: buy 1 unit at price 831.330017, total balance 9153.229918
# day 77: buy 1 unit at price 828.640015, total balance 8324.589903
# day 80, sell 1 unit at price 835.239990, investment 0.470327 %, total balance 9159.829893,
# day 81: buy 1 unit at price 830.630005, total balance 8329.199888
# day 82: buy 1 unit at price 829.080017, total balance 7500.119871
# day 83, sell 1 unit at price 827.780029, investment -0.103783 %, total balance 8327.899900,
# day 84, sell 1 unit at price 831.909973, investment 0.154096 %, total balance 9159.809873,
# day 86, sell 1 unit at price 838.679993, investment 1.157907 %, total balance 9998.489866,
# day 91: buy 1 unit at price 848.780029, total balance 9149.709837
# day 92, sell 1 unit at price 852.119995, investment 0.393502 %, total balance 10001.829832,
# day 94: buy 1 unit at price 830.460022, total balance 9171.369810
# day 95, sell 1 unit at price 829.590027, investment -0.104761 %, total balance 10000.959837,
# day 97: buy 1 unit at price 814.429993, total balance 9186.529844
# day 98: buy 1 unit at price 819.510010, total balance 8367.019834
# day 99, sell 1 unit at price 820.919983, investment 0.796875 %, total balance 9187.939817,
# day 103: buy 1 unit at price 838.549988, total balance 8349.389829
# day 104: buy 1 unit at price 834.570007, total balance 7514.819822
# day 105: buy 1 unit at price 831.409973, total balance 6683.409849
# day 106, sell 1 unit at price 827.880005, investment 1.021341 %, total balance 7511.289854,
# day 107: buy 1 unit at price 824.669983, total balance 6686.619871
# day 108, sell 1 unit at price 824.729980, investment -1.648084 %, total balance 7511.349851,
# day 109: buy 1 unit at price 823.349976, total balance 6687.999875
# day 110: buy 1 unit at price 824.320007, total balance 5863.679868
# day 112, sell 1 unit at price 837.169983, investment 0.311535 %, total balance 6700.849851,
# day 113: buy 1 unit at price 836.820007, total balance 5864.029844
# day 114: buy 1 unit at price 838.210022, total balance 5025.819822
# day 115, sell 1 unit at price 841.650024, investment 1.231649 %, total balance 5867.469846,
# day 116: buy 1 unit at price 843.190002, total balance 5024.279844
# day 118, sell 1 unit at price 872.299988, investment 5.775644 %, total balance 5896.579832,
# day 119, sell 1 unit at price 871.729980, investment 5.875995 %, total balance 6768.309812,
# day 120: buy 1 unit at price 874.250000, total balance 5894.059812
# day 121, sell 1 unit at price 905.960022, investment 9.903923 %, total balance 6800.019834,
# day 122: buy 1 unit at price 912.570007, total balance 5887.449827
# day 124, sell 1 unit at price 927.039978, investment 10.781288 %, total balance 6814.489805,
# day 125: buy 1 unit at price 931.659973, total balance 5882.829832
# day 127: buy 1 unit at price 934.299988, total balance 4948.529844
# day 128, sell 1 unit at price 932.169983, investment 11.209596 %, total balance 5880.699827,
# day 130: buy 1 unit at price 930.599976, total balance 4950.099851
# day 132: buy 1 unit at price 937.080017, total balance 4013.019834
# day 134, sell 1 unit at price 919.619995, investment 9.064386 %, total balance 4932.639829,
# day 135, sell 1 unit at price 930.239990, investment 6.404345 %, total balance 5862.879819,
# day 139, sell 1 unit at price 954.960022, investment 4.645125 %, total balance 6817.839841,
# day 140, sell 1 unit at price 969.539978, investment 4.065862 %, total balance 7787.379819,
# day 141, sell 1 unit at price 971.469971, investment 3.978378 %, total balance 8758.849790,
# day 142: buy 1 unit at price 975.880005, total balance 7782.969785
# day 143: buy 1 unit at price 964.859985, total balance 6818.109800
# day 149, sell 1 unit at price 983.409973, investment 5.674833 %, total balance 7801.519773,
# day 150, sell 1 unit at price 949.830017, investment 1.360610 %, total balance 8751.349790,
# day 151: buy 1 unit at price 942.900024, total balance 7808.449766
# day 153: buy 1 unit at price 950.760010, total balance 6857.689756
# day 154: buy 1 unit at price 942.309998, total balance 5915.379758
# day 158, sell 1 unit at price 959.450012, investment -1.683608 %, total balance 6874.829770,
# day 159, sell 1 unit at price 957.090027, investment -0.805294 %, total balance 7831.919797,
# day 160: buy 1 unit at price 965.590027, total balance 6866.329770
# day 162: buy 1 unit at price 927.330017, total balance 5938.999753
# day 164, sell 1 unit at price 917.789978, investment -2.663066 %, total balance 6856.789731,
# day 165: buy 1 unit at price 908.729980, total balance 5948.059751
# day 166, sell 1 unit at price 898.700012, investment -5.475619 %, total balance 6846.759763,
# day 167: buy 1 unit at price 911.710022, total balance 5935.049741
# day 168: buy 1 unit at price 906.690002, total balance 5028.359739
# day 169, sell 1 unit at price 918.590027, investment -2.517215 %, total balance 5946.949766,
# day 170: buy 1 unit at price 928.799988, total balance 5018.149778
# day 171, sell 1 unit at price 930.090027, investment -3.676509 %, total balance 5948.239805,
# day 174, sell 1 unit at price 955.989990, investment 3.090590 %, total balance 6904.229795,
# day 175, sell 1 unit at price 953.419983, investment 4.917853 %, total balance 7857.649778,
# day 176, sell 1 unit at price 965.400024, investment 5.888934 %, total balance 8823.049802,
# day 178, sell 1 unit at price 968.150024, investment 6.778504 %, total balance 9791.199826,
# day 179: buy 1 unit at price 972.919983, total balance 8818.279843
# day 180: buy 1 unit at price 980.340027, total balance 7837.939816
# day 181: buy 1 unit at price 950.700012, total balance 6887.239804
# day 182, sell 1 unit at price 947.799988, investment 2.045650 %, total balance 7835.039792,
# day 183: buy 1 unit at price 934.090027, total balance 6900.949765
# day 184, sell 1 unit at price 941.530029, investment -3.226365 %, total balance 7842.479794,
# day 188, sell 1 unit at price 923.650024, investment -5.782688 %, total balance 8766.129818,
# day 190, sell 1 unit at price 929.359985, investment -2.244665 %, total balance 9695.489803,
# day 192, sell 1 unit at price 922.900024, investment -1.197958 %, total balance 10618.389827,
# day 198: buy 1 unit at price 910.979980, total balance 9707.409847
# day 199: buy 1 unit at price 910.669983, total balance 8796.739864
# day 200: buy 1 unit at price 906.659973, total balance 7890.079891
# day 201: buy 1 unit at price 924.690002, total balance 6965.389889
# day 202, sell 1 unit at price 927.000000, investment 1.758548 %, total balance 7892.389889,
# day 203: buy 1 unit at price 921.280029, total balance 6971.109860
# day 204, sell 1 unit at price 915.890015, investment 0.573208 %, total balance 7886.999875,
# day 206, sell 1 unit at price 921.289978, investment 1.613615 %, total balance 8808.289853,
# day 207, sell 1 unit at price 929.570007, investment 0.527745 %, total balance 9737.859860,
# day 209: buy 1 unit at price 937.340027, total balance 8800.519833
# day 210, sell 1 unit at price 928.450012, investment 0.778263 %, total balance 9728.969845,
# day 211: buy 1 unit at price 927.809998, total balance 8801.159847
# day 213, sell 1 unit at price 926.500000, investment -1.156467 %, total balance 9727.659847,
# day 214, sell 1 unit at price 929.080017, investment 0.136884 %, total balance 10656.739864,
# day 216: buy 1 unit at price 935.090027, total balance 9721.649837
# day 217, sell 1 unit at price 925.109985, investment -1.067281 %, total balance 10646.759822,
# day 218: buy 1 unit at price 920.289978, total balance 9726.469844
# day 219, sell 1 unit at price 915.000000, investment -0.574816 %, total balance 10641.469844,
# day 223: buy 1 unit at price 928.530029, total balance 9712.939815
# day 225, sell 1 unit at price 924.859985, investment -0.395253 %, total balance 10637.799800,
# day 228: buy 1 unit at price 959.109985, total balance 9678.689815
# day 229, sell 1 unit at price 953.270020, investment -0.608894 %, total balance 10631.959835,
# day 231: buy 1 unit at price 951.679993, total balance 9680.279842
# day 237, sell 1 unit at price 987.830017, investment 3.798548 %, total balance 10668.109859,
# day 247: buy 1 unit at price 972.559998, total balance 9695.549861
# day 248: buy 1 unit at price 1019.270020, total balance 8676.279841
# day 249, sell 1 unit at price 1017.109985, investment 4.580693 %, total balance 9693.389826,
# day 250: buy 1 unit at price 1016.640015, total balance 8676.749811

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
