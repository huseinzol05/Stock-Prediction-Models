# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 1
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# epoch: 10, total rewards: 1025.384820.3, cost: 7.711813, total money: 1313.474846
# epoch: 20, total rewards: 1133.360230.3, cost: 4.324252, total money: 3358.230286
# epoch: 30, total rewards: 808.480033.3, cost: 27.184271, total money: 4885.910024
# epoch: 40, total rewards: -42.805112.3, cost: 33.246643, total money: 7920.814883
# epoch: 50, total rewards: 462.149783.3, cost: 24.759113, total money: 9442.879763
# epoch: 60, total rewards: 373.539671.3, cost: 37.349476, total money: 10373.539671
# epoch: 70, total rewards: 240.479490.3, cost: 115.375275, total money: 10240.479490
# epoch: 80, total rewards: 521.654908.3, cost: 20.545702, total money: 1982.764894
# epoch: 90, total rewards: 486.859987.3, cost: 71.608681, total money: 9470.219972
# epoch: 100, total rewards: 233.600101.3, cost: 7.579909, total money: 10233.600101
# epoch: 110, total rewards: -24.324889.3, cost: 24.449669, total money: 9975.675111
# epoch: 120, total rewards: 128.265074.3, cost: 48.196480, total money: 10128.265074
# epoch: 130, total rewards: 222.620057.3, cost: 79.013763, total money: 10222.620057
# epoch: 140, total rewards: 345.709960.3, cost: 29.371716, total money: 10345.709960
# epoch: 150, total rewards: -28.110046.3, cost: 24.815056, total money: 9971.889954
# epoch: 160, total rewards: 669.829955.3, cost: 68.039909, total money: 10669.829955
# epoch: 170, total rewards: 72.355097.3, cost: 82.145020, total money: 10072.355097
# epoch: 180, total rewards: 131.220091.3, cost: 97.540756, total money: 10131.220091
# epoch: 190, total rewards: 85.684874.3, cost: 60.007385, total money: 10085.684874
# epoch: 200, total rewards: 127.830079.3, cost: 94.811501, total money: 10127.830079

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 1: buy 1 unit at price 762.130005, total balance 9237.869995
# day 4: buy 1 unit at price 790.510010, total balance 8447.359985
# day 5: buy 1 unit at price 785.309998, total balance 7662.049987
# day 6, sell 1 unit at price 762.559998, investment 0.056420 %, total balance 8424.609985,
# day 7, sell 1 unit at price 754.020020, investment -4.616006 %, total balance 9178.630005,
# day 8: buy 1 unit at price 736.080017, total balance 8442.549988
# day 9, sell 1 unit at price 758.489990, investment -3.415213 %, total balance 9201.039978,
# day 10: buy 1 unit at price 764.479980, total balance 8436.559998
# day 14: buy 1 unit at price 768.270020, total balance 7668.289978
# day 15, sell 1 unit at price 760.989990, investment 3.384139 %, total balance 8429.279968,
# day 17, sell 1 unit at price 768.239990, investment 0.491839 %, total balance 9197.519958,
# day 18: buy 1 unit at price 770.840027, total balance 8426.679931
# day 19: buy 1 unit at price 758.039978, total balance 7668.639953
# day 20: buy 1 unit at price 747.919983, total balance 6920.719970
# day 21, sell 1 unit at price 750.500000, investment -2.312991 %, total balance 7671.219970,
# day 22: buy 1 unit at price 762.520020, total balance 6908.699950
# day 23: buy 1 unit at price 759.109985, total balance 6149.589965
# day 24, sell 1 unit at price 771.190002, investment 0.045402 %, total balance 6920.779967,
# day 27, sell 1 unit at price 789.270020, investment 4.119841 %, total balance 7710.049987,
# day 28, sell 1 unit at price 796.099976, investment 6.441865 %, total balance 8506.149963,
# day 32, sell 1 unit at price 794.200012, investment 4.154644 %, total balance 9300.349975,
# day 33: buy 1 unit at price 796.419983, total balance 8503.929992
# day 35, sell 1 unit at price 791.260010, investment 4.235226 %, total balance 9295.190002,
# day 36: buy 1 unit at price 789.909973, total balance 8505.280029
# day 37: buy 1 unit at price 791.549988, total balance 7713.730041
# day 38, sell 1 unit at price 785.049988, investment -1.427638 %, total balance 8498.780029,
# day 39, sell 1 unit at price 782.789978, investment -0.901368 %, total balance 9281.570007,
# day 40, sell 1 unit at price 771.820007, investment -2.492575 %, total balance 10053.390014,
# day 42: buy 1 unit at price 786.900024, total balance 9266.489990
# day 43: buy 1 unit at price 794.020020, total balance 8472.469970
# day 44: buy 1 unit at price 806.150024, total balance 7666.319946
# day 45, sell 1 unit at price 806.650024, investment 2.509849 %, total balance 8472.969970,
# day 46: buy 1 unit at price 804.789978, total balance 7668.179992
# day 47, sell 1 unit at price 807.909973, investment 1.749320 %, total balance 8476.089965,
# day 49, sell 1 unit at price 807.880005, investment 0.214598 %, total balance 9283.969970,
# day 50: buy 1 unit at price 804.609985, total balance 8479.359985
# day 51: buy 1 unit at price 806.070007, total balance 7673.289978
# day 52, sell 1 unit at price 802.174988, investment -0.324928 %, total balance 8475.464966,
# day 53: buy 1 unit at price 805.020020, total balance 7670.444946
# day 54: buy 1 unit at price 819.309998, total balance 6851.134948
# day 55, sell 1 unit at price 823.869995, investment 2.393708 %, total balance 7675.004943,
# day 57, sell 1 unit at price 832.150024, investment 3.235453 %, total balance 8507.154967,
# day 58: buy 1 unit at price 823.309998, total balance 7683.844969
# day 59: buy 1 unit at price 802.320007, total balance 6881.524962
# day 60, sell 1 unit at price 796.789978, investment -1.022340 %, total balance 7678.314940,
# day 61: buy 1 unit at price 795.695007, total balance 6882.619933
# day 62, sell 1 unit at price 798.530029, investment -2.536277 %, total balance 7681.149962,
# day 64, sell 1 unit at price 801.340027, investment -2.668493 %, total balance 8482.489989,
# day 65, sell 1 unit at price 806.969971, investment 0.579565 %, total balance 9289.459960,
# day 67: buy 1 unit at price 809.559998, total balance 8479.899962
# day 68, sell 1 unit at price 813.669983, investment 2.259028 %, total balance 9293.569945,
# day 69, sell 1 unit at price 819.239990, investment 1.195710 %, total balance 10112.809935,
# day 70: buy 1 unit at price 820.450012, total balance 9292.359923
# day 71: buy 1 unit at price 818.979980, total balance 8473.379943
# day 72: buy 1 unit at price 824.159973, total balance 7649.219970
# day 73: buy 1 unit at price 828.070007, total balance 6821.149963
# day 74, sell 1 unit at price 831.659973, investment 1.366319 %, total balance 7652.809936,
# day 75: buy 1 unit at price 830.760010, total balance 6822.049926
# day 79, sell 1 unit at price 823.210022, investment 0.516501 %, total balance 7645.259948,
# day 80, sell 1 unit at price 835.239990, investment 1.344401 %, total balance 8480.499938,
# day 81: buy 1 unit at price 830.630005, total balance 7649.869933
# day 82: buy 1 unit at price 829.080017, total balance 6820.789916
# day 85: buy 1 unit at price 835.369995, total balance 5985.419921
# day 86: buy 1 unit at price 838.679993, total balance 5146.739928
# day 87: buy 1 unit at price 843.250000, total balance 4303.489928
# day 88, sell 1 unit at price 845.539978, investment 2.109722 %, total balance 5149.029906,
# day 89: buy 1 unit at price 845.619995, total balance 4303.409911
# day 90, sell 1 unit at price 847.200012, investment 1.978911 %, total balance 5150.609923,
# day 91: buy 1 unit at price 848.780029, total balance 4301.829894
# day 92: buy 1 unit at price 852.119995, total balance 3449.709899
# day 93, sell 1 unit at price 848.400024, investment 2.139342 %, total balance 4298.109923,
# day 94: buy 1 unit at price 830.460022, total balance 3467.649901
# day 95, sell 1 unit at price 829.590027, investment 0.061515 %, total balance 4297.239928,
# day 96: buy 1 unit at price 817.580017, total balance 3479.659911
# day 97: buy 1 unit at price 814.429993, total balance 2665.229918
# day 99: buy 1 unit at price 820.919983, total balance 1844.309935
# day 100: buy 1 unit at price 831.409973, total balance 1012.899962
# day 105: buy 1 unit at price 831.409973, total balance 181.489989
# day 106, sell 1 unit at price 827.880005, investment -0.896607 %, total balance 1009.369994,
# day 108: buy 1 unit at price 824.729980, total balance 184.640014
# day 109, sell 1 unit at price 823.349976, investment -1.827874 %, total balance 1007.989990,
# day 110: buy 1 unit at price 824.320007, total balance 183.669983
# day 111, sell 1 unit at price 823.559998, investment -2.335014 %, total balance 1007.229981,
# day 113, sell 1 unit at price 836.820007, investment -1.040655 %, total balance 1844.049988,
# day 114, sell 1 unit at price 838.210022, investment -1.245318 %, total balance 2682.260010,
# day 116: buy 1 unit at price 843.190002, total balance 1839.070008
# day 117: buy 1 unit at price 862.760010, total balance 976.309998
# day 118: buy 1 unit at price 872.299988, total balance 104.010010
# day 121, sell 1 unit at price 905.960022, investment 6.318362 %, total balance 1009.970032,
# day 122, sell 1 unit at price 912.570007, investment 9.887289 %, total balance 1922.540039,
# day 123, sell 1 unit at price 916.440002, investment 12.091781 %, total balance 2838.980041,
# day 124, sell 1 unit at price 927.039978, investment 13.826847 %, total balance 3766.020019,
# day 125, sell 1 unit at price 931.659973, investment 13.489742 %, total balance 4697.679992,
# day 126, sell 1 unit at price 927.130005, investment 11.512976 %, total balance 5624.809997,
# day 127: buy 1 unit at price 934.299988, total balance 4690.510009
# day 128: buy 1 unit at price 932.169983, total balance 3758.340026
# day 129: buy 1 unit at price 928.780029, total balance 2829.559997
# day 130: buy 1 unit at price 930.599976, total balance 1898.960021
# day 131: buy 1 unit at price 932.219971, total balance 966.740050
# day 132, sell 1 unit at price 937.080017, investment 12.709740 %, total balance 1903.820067,
# day 134, sell 1 unit at price 919.619995, investment 11.505586 %, total balance 2823.440062,
# day 135: buy 1 unit at price 930.239990, total balance 1893.200072
# day 137: buy 1 unit at price 941.859985, total balance 951.340087
# day 138: buy 1 unit at price 948.820007, total balance 2.520080
# day 139, sell 1 unit at price 954.960022, investment 15.848216 %, total balance 957.480102,
# day 142, sell 1 unit at price 975.880005, investment 15.736667 %, total balance 1933.360107,
# day 144: buy 1 unit at price 966.950012, total balance 966.410095
# day 145, sell 1 unit at price 975.599976, investment 13.078952 %, total balance 1942.010071,
# day 148, sell 1 unit at price 980.940002, investment 12.454433 %, total balance 2922.950073,
# day 149: buy 1 unit at price 983.409973, total balance 1939.540100
# day 150: buy 1 unit at price 949.830017, total balance 989.710083
# day 151, sell 1 unit at price 942.900024, investment 0.920479 %, total balance 1932.610107,
# day 152, sell 1 unit at price 953.400024, investment 2.277486 %, total balance 2886.010131,
# day 154: buy 1 unit at price 942.309998, total balance 1943.700133
# day 155, sell 1 unit at price 939.780029, investment 1.184349 %, total balance 2883.480162,
# day 156, sell 1 unit at price 957.369995, investment 2.876641 %, total balance 3840.850157,
# day 157: buy 1 unit at price 950.630005, total balance 2890.220152
# day 158: buy 1 unit at price 959.450012, total balance 1930.770140
# day 159: buy 1 unit at price 957.090027, total balance 973.680113
# day 160, sell 1 unit at price 965.590027, investment 3.579633 %, total balance 1939.270140,
# day 162, sell 1 unit at price 927.330017, investment -0.312820 %, total balance 2866.600157,
# day 163, sell 1 unit at price 940.489990, investment -0.145456 %, total balance 3807.090147,
# day 164, sell 1 unit at price 917.789978, investment -3.270381 %, total balance 4724.880125,
# day 165: buy 1 unit at price 908.729980, total balance 3816.150145
# day 167, sell 1 unit at price 911.710022, investment -5.712807 %, total balance 4727.860167,
# day 169: buy 1 unit at price 918.590027, total balance 3809.270140
# day 170, sell 1 unit at price 928.799988, investment -5.553125 %, total balance 4738.070128,
# day 171, sell 1 unit at price 930.090027, investment -2.078266 %, total balance 5668.160155,
# day 173: buy 1 unit at price 947.159973, total balance 4721.000182
# day 174: buy 1 unit at price 955.989990, total balance 3765.010192
# day 176: buy 1 unit at price 965.400024, total balance 2799.610168
# day 177: buy 1 unit at price 970.890015, total balance 1828.720153
# day 180: buy 1 unit at price 980.340027, total balance 848.380126
# day 181, sell 1 unit at price 950.700012, investment 0.890367 %, total balance 1799.080138,
# day 184, sell 1 unit at price 941.530029, investment -0.957257 %, total balance 2740.610167,
# day 185: buy 1 unit at price 930.500000, total balance 1810.110167
# day 186, sell 1 unit at price 930.830017, investment -2.982958 %, total balance 2740.940184,
# day 188, sell 1 unit at price 923.650024, investment -3.493925 %, total balance 3664.590208,
# day 189, sell 1 unit at price 927.960022, investment 2.116145 %, total balance 4592.550230,
# day 190, sell 1 unit at price 929.359985, investment 1.172444 %, total balance 5521.910215,
# day 191, sell 1 unit at price 926.789978, investment -2.150639 %, total balance 6448.700193,
# day 193, sell 1 unit at price 907.239990, investment -5.099426 %, total balance 7355.940183,
# day 194, sell 1 unit at price 914.390015, investment -5.283821 %, total balance 8270.330198,
# day 196: buy 1 unit at price 922.219971, total balance 7348.110227
# day 197, sell 1 unit at price 926.960022, investment -4.524714 %, total balance 8275.070249,
# day 203, sell 1 unit at price 921.280029, investment -6.024440 %, total balance 9196.350278,
# day 205, sell 1 unit at price 913.809998, investment -1.793660 %, total balance 10110.160276,
# day 206: buy 1 unit at price 921.289978, total balance 9188.870298
# day 207, sell 1 unit at price 929.570007, investment 0.796994 %, total balance 10118.440305,
# day 208, sell 1 unit at price 939.330017, investment 1.958128 %, total balance 11057.770322,
# day 211: buy 1 unit at price 927.809998, total balance 10129.960324
# day 212, sell 1 unit at price 935.950012, investment 0.877336 %, total balance 11065.910336,
# day 213: buy 1 unit at price 926.500000, total balance 10139.410336
# day 214, sell 1 unit at price 929.080017, investment 0.278469 %, total balance 11068.490353,
# day 216: buy 1 unit at price 935.090027, total balance 10133.400326
# day 217, sell 1 unit at price 925.109985, investment -1.067281 %, total balance 11058.510311,
# day 223: buy 1 unit at price 928.530029, total balance 10129.980282
# day 224: buy 1 unit at price 920.969971, total balance 9209.010311
# day 225, sell 1 unit at price 924.859985, investment -0.395253 %, total balance 10133.870296,
# day 226: buy 1 unit at price 944.489990, total balance 9189.380306
# day 228, sell 1 unit at price 959.109985, investment 4.141287 %, total balance 10148.490291,
# day 229, sell 1 unit at price 953.270020, investment 0.929605 %, total balance 11101.760311,
# day 230: buy 1 unit at price 957.789978, total balance 10143.970333
# day 231: buy 1 unit at price 951.679993, total balance 9192.290340
# day 233: buy 1 unit at price 978.890015, total balance 8213.400325
# day 236, sell 1 unit at price 989.250000, investment 3.284647 %, total balance 9202.650325,
# day 237: buy 1 unit at price 987.830017, total balance 8214.820308
# day 238, sell 1 unit at price 989.679993, investment 3.992939 %, total balance 9204.500301,
# day 239, sell 1 unit at price 992.000000, investment 1.339270 %, total balance 10196.500301,
# day 240: buy 1 unit at price 992.179993, total balance 9204.320308
# day 241: buy 1 unit at price 992.809998, total balance 8211.510310
# day 242, sell 1 unit at price 984.450012, investment -0.342165 %, total balance 9195.960322,
# day 244: buy 1 unit at price 968.450012, total balance 8227.510310
# day 245, sell 1 unit at price 970.539978, investment -2.181057 %, total balance 9198.050288,
# day 246: buy 1 unit at price 973.330017, total balance 8224.720271
# day 247, sell 1 unit at price 972.559998, investment -2.039665 %, total balance 9197.280269,
# day 250, sell 1 unit at price 1016.640015, investment 4.975993 %, total balance 10213.920284,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
