# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
import pkg_resources
import types


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# seaborn==0.9.0
# pandas==0.23.4
# numpy==1.14.5
# matplotlib==3.0.2

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / np.std(rewards)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1
initial_money = 10000

model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent.fit(iterations = 500, checkpoint = 10)
# Out:
# iter 10. reward: 27.931850
# iter 20. reward: 26.236249
# iter 30. reward: 28.871800
# iter 40. reward: 29.301248
# iter 50. reward: 27.093949
# iter 60. reward: 28.088450
# iter 70. reward: 29.700101
# iter 80. reward: 26.530800
# iter 90. reward: 31.022900
# iter 100. reward: 30.154701
# iter 110. reward: 30.970004
# iter 120. reward: 29.763403
# iter 130. reward: 32.103303
# iter 140. reward: 30.502103
# iter 150. reward: 31.868202
# iter 160. reward: 34.120703
# iter 170. reward: 34.685903
# iter 180. reward: 33.421602
# iter 190. reward: 33.277900
# iter 200. reward: 35.347803
# iter 210. reward: 36.843201
# iter 220. reward: 35.823052
# iter 230. reward: 37.636902
# iter 240. reward: 35.351301
# iter 250. reward: 37.379652
# iter 260. reward: 38.785352
# iter 270. reward: 36.292951
# iter 280. reward: 37.830151
# iter 290. reward: 38.366350
# iter 300. reward: 38.399101
# iter 310. reward: 36.492101
# iter 320. reward: 37.540300
# iter 330. reward: 37.790601
# iter 340. reward: 38.534902
# iter 350. reward: 37.959701
# iter 360. reward: 38.271102
# iter 370. reward: 38.712502
# iter 380. reward: 38.861502
# iter 390. reward: 38.758600
# iter 400. reward: 38.667902
# iter 410. reward: 38.481402
# iter 420. reward: 35.339901
# iter 430. reward: 37.417501
# iter 440. reward: 28.606702
# iter 450. reward: 38.937502
# iter 460. reward: 37.261202
# iter 470. reward: 38.785000
# iter 480. reward: 35.819802
# iter 490. reward: 37.982202
# iter 500. reward: 39.443602
# time taken to train: 33.27175831794739 seconds

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# day 0: buy 1 unit at price 768.700012, total balance 9231.299988
# day 1: buy 1 unit at price 762.130005, total balance 8469.169983
# day 2: buy 1 unit at price 762.020020, total balance 7707.149963
# day 5, sell 1 unit at price 785.309998, investment 2.160789 %, total balance 8492.459961,
# day 6: buy 1 unit at price 762.559998, total balance 7729.899963
# day 7: buy 1 unit at price 754.020020, total balance 6975.879943
# day 8: buy 1 unit at price 736.080017, total balance 6239.799926
# day 9: buy 1 unit at price 758.489990, total balance 5481.309936
# day 10: buy 1 unit at price 764.479980, total balance 4716.829956
# day 11: buy 1 unit at price 771.229980, total balance 3945.599976
# day 15, sell 1 unit at price 760.989990, investment -0.149583 %, total balance 4706.589966,
# day 16: buy 1 unit at price 761.679993, total balance 3944.909973
# day 19: buy 1 unit at price 758.039978, total balance 3186.869995
# day 20: buy 1 unit at price 747.919983, total balance 2438.950012
# day 21: buy 1 unit at price 750.500000, total balance 1688.450012
# day 23: buy 1 unit at price 759.109985, total balance 929.340027
# day 29: buy 1 unit at price 797.070007, total balance 132.270020
# day 30, sell 1 unit at price 797.849976, investment 4.701970 %, total balance 930.119996,
# day 31: buy 1 unit at price 790.799988, total balance 139.320008
# day 38, sell 1 unit at price 785.049988, investment 2.949275 %, total balance 924.369996,
# day 39, sell 1 unit at price 782.789978, investment 3.815543 %, total balance 1707.159974,
# day 40: buy 1 unit at price 771.820007, total balance 935.339967
# day 42, sell 1 unit at price 786.900024, investment 6.904142 %, total balance 1722.239991,
# day 43, sell 1 unit at price 794.020020, investment 4.684311 %, total balance 2516.260011,
# day 45, sell 1 unit at price 806.650024, investment 5.516174 %, total balance 3322.910035,
# day 46, sell 1 unit at price 804.789978, investment 4.351490 %, total balance 4127.700013,
# day 48: buy 1 unit at price 806.359985, total balance 3321.340028
# day 50: buy 1 unit at price 804.609985, total balance 2516.730043
# day 51: buy 1 unit at price 806.070007, total balance 1710.660036
# day 52: buy 1 unit at price 802.174988, total balance 908.485048
# day 53: buy 1 unit at price 805.020020, total balance 103.465028
# day 55, sell 1 unit at price 823.869995, investment 8.164846 %, total balance 927.335023,
# day 58, sell 1 unit at price 823.309998, investment 8.610366 %, total balance 1750.645021,
# day 59, sell 1 unit at price 802.320007, investment 7.273509 %, total balance 2552.965028,
# day 60: buy 1 unit at price 796.789978, total balance 1756.175050
# day 61: buy 1 unit at price 795.695007, total balance 960.480043
# day 62: buy 1 unit at price 798.530029, total balance 161.950014
# day 69, sell 1 unit at price 819.239990, investment 9.159226 %, total balance 981.190004,
# day 70, sell 1 unit at price 820.450012, investment 8.080519 %, total balance 1801.640016,
# day 71: buy 1 unit at price 818.979980, total balance 982.660036
# day 72: buy 1 unit at price 824.159973, total balance 158.500063
# day 74, sell 1 unit at price 831.659973, investment 4.339640 %, total balance 990.160036,
# day 75: buy 1 unit at price 830.760010, total balance 159.400026
# day 82, sell 1 unit at price 829.080017, investment 4.840671 %, total balance 988.480043,
# day 84, sell 1 unit at price 831.909973, investment 7.785490 %, total balance 1820.390016,
# day 86, sell 1 unit at price 838.679993, investment 4.008136 %, total balance 2659.070009,
# day 89, sell 1 unit at price 845.619995, investment 5.096881 %, total balance 3504.690004,
# day 91, sell 1 unit at price 848.780029, investment 5.298550 %, total balance 4353.470033,
# day 92, sell 1 unit at price 852.119995, investment 6.226198 %, total balance 5205.590028,
# day 93, sell 1 unit at price 848.400024, investment 5.388686 %, total balance 6053.990052,
# day 94: buy 1 unit at price 830.460022, total balance 5223.530030
# day 95: buy 1 unit at price 829.590027, total balance 4393.940003
# day 96: buy 1 unit at price 817.580017, total balance 3576.359986
# day 97: buy 1 unit at price 814.429993, total balance 2761.929993
# day 98: buy 1 unit at price 819.510010, total balance 1942.419983
# day 99: buy 1 unit at price 820.919983, total balance 1121.500000
# day 102, sell 1 unit at price 829.559998, investment 4.112755 %, total balance 1951.059998,
# day 104, sell 1 unit at price 834.570007, investment 4.885666 %, total balance 2785.630005,
# day 105, sell 1 unit at price 831.409973, investment 4.117559 %, total balance 3617.039978,
# day 106: buy 1 unit at price 827.880005, total balance 2789.159973
# day 107: buy 1 unit at price 824.669983, total balance 1964.489990
# day 108: buy 1 unit at price 824.729980, total balance 1139.760010
# day 109: buy 1 unit at price 823.349976, total balance 316.410034
# day 129, sell 1 unit at price 928.780029, investment 13.406927 %, total balance 1245.190063,
# day 132, sell 1 unit at price 937.080017, investment 13.701229 %, total balance 2182.270080,
# day 133, sell 1 unit at price 943.000000, investment 13.510519 %, total balance 3125.270080,
# day 134, sell 1 unit at price 919.619995, investment 10.736215 %, total balance 4044.890075,
# day 137, sell 1 unit at price 941.859985, investment 13.533186 %, total balance 4986.750060,
# day 138, sell 1 unit at price 948.820007, investment 16.052250 %, total balance 5935.570067,
# day 139, sell 1 unit at price 954.960022, investment 17.255016 %, total balance 6890.530089,
# day 141, sell 1 unit at price 971.469971, investment 18.542783 %, total balance 7862.000060,
# day 142, sell 1 unit at price 975.880005, investment 18.876386 %, total balance 8837.880065,
# day 143, sell 1 unit at price 964.859985, investment 16.545874 %, total balance 9802.740050,
# day 144, sell 1 unit at price 966.950012, investment 17.252966 %, total balance 10769.690062,
# day 146, sell 1 unit at price 983.679993, investment 19.272976 %, total balance 11753.370055,
# day 147, sell 1 unit at price 976.570007, investment 18.609344 %, total balance 12729.940062,
# day 151: buy 1 unit at price 942.900024, total balance 11787.040038
# day 152, sell 1 unit at price 953.400024, investment 1.113586 %, total balance 12740.440062,
# day 154: buy 1 unit at price 942.309998, total balance 11798.130064
# day 155: buy 1 unit at price 939.780029, total balance 10858.350035
# day 157, sell 1 unit at price 950.630005, investment 0.882937 %, total balance 11808.980040,
# day 158, sell 1 unit at price 959.450012, investment 2.093041 %, total balance 12768.430052,
# day 159: buy 1 unit at price 957.090027, total balance 11811.340025
# day 160, sell 1 unit at price 965.590027, investment 0.888109 %, total balance 12776.930052,
# day 162: buy 1 unit at price 927.330017, total balance 11849.600035
# day 163: buy 1 unit at price 940.489990, total balance 10909.110045
# day 164: buy 1 unit at price 917.789978, total balance 9991.320067
# day 165: buy 1 unit at price 908.729980, total balance 9082.590087
# day 166: buy 1 unit at price 898.700012, total balance 8183.890075
# day 167: buy 1 unit at price 911.710022, total balance 7272.180053
# day 168: buy 1 unit at price 906.690002, total balance 6365.490051
# day 173, sell 1 unit at price 947.159973, investment 2.138393 %, total balance 7312.650024,
# day 174, sell 1 unit at price 955.989990, investment 1.648077 %, total balance 8268.640014,
# day 175, sell 1 unit at price 953.419983, investment 3.882152 %, total balance 9222.059997,
# day 177, sell 1 unit at price 970.890015, investment 6.840320 %, total balance 10192.950012,
# day 178, sell 1 unit at price 968.150024, investment 7.727830 %, total balance 11161.100036,
# day 180, sell 1 unit at price 980.340027, investment 7.527613 %, total balance 12141.440063,
# day 181, sell 1 unit at price 950.700012, investment 4.853920 %, total balance 13092.140075,
# day 182: buy 1 unit at price 947.799988, total balance 12144.340087
# day 183: buy 1 unit at price 934.090027, total balance 11210.250060
# day 184: buy 1 unit at price 941.530029, total balance 10268.720031
# day 185: buy 1 unit at price 930.500000, total balance 9338.220031
# day 186: buy 1 unit at price 930.830017, total balance 8407.390014
# day 187: buy 1 unit at price 930.390015, total balance 7476.999999
# day 188, sell 1 unit at price 923.650024, investment -2.548002 %, total balance 8400.650023,
# day 189, sell 1 unit at price 927.960022, investment -0.656254 %, total balance 9328.610045,
# day 191, sell 1 unit at price 926.789978, investment -1.565542 %, total balance 10255.400023,
# day 193: buy 1 unit at price 907.239990, total balance 9348.160033
# day 194: buy 1 unit at price 914.390015, total balance 8433.770018
# day 195: buy 1 unit at price 922.669983, total balance 7511.100035
# day 196: buy 1 unit at price 922.219971, total balance 6588.880064
# day 198: buy 1 unit at price 910.979980, total balance 5677.900084
# day 199: buy 1 unit at price 910.669983, total balance 4767.230101
# day 200: buy 1 unit at price 906.659973, total balance 3860.570128
# day 201: buy 1 unit at price 924.690002, total balance 2935.880126
# day 203: buy 1 unit at price 921.280029, total balance 2014.600097
# day 204: buy 1 unit at price 915.890015, total balance 1098.710082
# day 206: buy 1 unit at price 921.289978, total balance 177.420104
# day 216, sell 1 unit at price 935.090027, investment 0.493286 %, total balance 1112.510131,
# day 218: buy 1 unit at price 920.289978, total balance 192.220153
# day 227, sell 1 unit at price 949.500000, investment 2.005735 %, total balance 1141.720153,
# day 228, sell 1 unit at price 959.109985, investment 3.086874 %, total balance 2100.830138,
# day 233, sell 1 unit at price 978.890015, investment 7.897582 %, total balance 3079.720153,
# day 234, sell 1 unit at price 977.000000, investment 6.847186 %, total balance 4056.720153,
# day 237, sell 1 unit at price 987.830017, investment 7.062117 %, total balance 5044.550170,
# day 238, sell 1 unit at price 989.679993, investment 7.314960 %, total balance 6034.230163,
# day 240, sell 1 unit at price 992.179993, investment 8.913479 %, total balance 7026.410156,
# day 242, sell 1 unit at price 984.450012, investment 8.101731 %, total balance 8010.860168,
# day 243, sell 1 unit at price 988.200012, investment 8.993453 %, total balance 8999.060180,
# day 244, sell 1 unit at price 968.450012, investment 4.732398 %, total balance 9967.510192,
# day 245, sell 1 unit at price 970.539978, investment 5.346903 %, total balance 10938.050170,
# day 247, sell 1 unit at price 972.559998, investment 6.187422 %, total balance 11910.610168,
# day 249, sell 1 unit at price 1017.109985, investment 10.400635 %, total balance 12927.720153,
# day 250, sell 1 unit at price 1016.640015, investment 10.469530 %, total balance 13944.360168,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
