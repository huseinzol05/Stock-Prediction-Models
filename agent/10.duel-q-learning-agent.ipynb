# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random


class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 512, activation = tf.nn.relu)
        tensor_action, tensor_validation = tf.split(feed,2,1)
        feed_action = tf.layers.dense(tensor_action, self.action_size)
        feed_validation = tf.layers.dense(tensor_validation, 1)
        self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-c7584e018993>:30: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# epoch: 10, total rewards: 111.760075.3, cost: 0.732796, total money: 10111.760075
# epoch: 20, total rewards: 70.940065.3, cost: 0.365644, total money: 10070.940065
# epoch: 30, total rewards: 105.190004.3, cost: 0.218199, total money: 10105.190004
# epoch: 40, total rewards: 96.590151.3, cost: 0.141329, total money: 10096.590151
# epoch: 50, total rewards: 22.150148.3, cost: 0.317125, total money: 10022.150148
# epoch: 60, total rewards: 21.260073.3, cost: 0.087481, total money: 10021.260073
# epoch: 70, total rewards: -1.889891.3, cost: 0.087621, total money: 9998.110109
# epoch: 80, total rewards: 25.170168.3, cost: 0.049968, total money: 10025.170168
# epoch: 90, total rewards: 47.420108.3, cost: 0.048697, total money: 10047.420108
# epoch: 100, total rewards: 70.710146.3, cost: 0.032923, total money: 10070.710146
# epoch: 110, total rewards: 107.470095.3, cost: 0.027796, total money: 10107.470095
# epoch: 120, total rewards: 73.380190.3, cost: 0.025961, total money: 10073.380190
# epoch: 130, total rewards: 72.750184.3, cost: 0.022524, total money: 10072.750184
# epoch: 140, total rewards: 67.720094.3, cost: 0.019348, total money: 10067.720094
# epoch: 150, total rewards: 138.470096.3, cost: 0.017712, total money: 10138.470096
# epoch: 160, total rewards: 96.890077.3, cost: 0.015675, total money: 10096.890077
# epoch: 170, total rewards: 47.480226.3, cost: 0.011994, total money: 10047.480226
# epoch: 180, total rewards: 67.430055.3, cost: 0.011915, total money: 10067.430055
# epoch: 190, total rewards: 90.830200.3, cost: 0.010580, total money: 10090.830200
# epoch: 200, total rewards: 102.240113.3, cost: 0.012800, total money: 10102.240113

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 1: buy 1 unit at price 762.130005, total balance 9237.869995
# day 3, sell 1 unit at price 782.520020, investment 2.675399 %, total balance 10020.390015,
# day 6: buy 1 unit at price 762.559998, total balance 9257.830017
# day 7, sell 1 unit at price 754.020020, investment -1.119909 %, total balance 10011.850037,
# day 8: buy 1 unit at price 736.080017, total balance 9275.770020
# day 10, sell 1 unit at price 764.479980, investment 3.858271 %, total balance 10040.250000,
# day 12: buy 1 unit at price 760.539978, total balance 9279.710022
# day 16, sell 1 unit at price 761.679993, investment 0.149895 %, total balance 10041.390015,
# day 22: buy 1 unit at price 762.520020, total balance 9278.869995
# day 23, sell 1 unit at price 759.109985, investment -0.447206 %, total balance 10037.979980,
# day 30: buy 1 unit at price 797.849976, total balance 9240.130004
# day 31, sell 1 unit at price 790.799988, investment -0.883623 %, total balance 10030.929992,
# day 33: buy 1 unit at price 796.419983, total balance 9234.510009
# day 35, sell 1 unit at price 791.260010, investment -0.647896 %, total balance 10025.770019,
# day 38: buy 1 unit at price 785.049988, total balance 9240.720031
# day 40, sell 1 unit at price 771.820007, investment -1.685241 %, total balance 10012.540038,
# day 46: buy 1 unit at price 804.789978, total balance 9207.750060
# day 47, sell 1 unit at price 807.909973, investment 0.387678 %, total balance 10015.660033,
# day 50: buy 1 unit at price 804.609985, total balance 9211.050048
# day 51, sell 1 unit at price 806.070007, investment 0.181457 %, total balance 10017.120055,
# day 52: buy 1 unit at price 802.174988, total balance 9214.945067
# day 53, sell 1 unit at price 805.020020, investment 0.354665 %, total balance 10019.965087,
# day 56: buy 1 unit at price 835.669983, total balance 9184.295104
# day 59: buy 1 unit at price 802.320007, total balance 8381.975097
# day 60: buy 1 unit at price 796.789978, total balance 7585.185119
# day 61: buy 1 unit at price 795.695007, total balance 6789.490112
# day 62, sell 1 unit at price 798.530029, investment -4.444333 %, total balance 7588.020141,
# day 63, sell 1 unit at price 801.489990, investment -0.103452 %, total balance 8389.510131,
# day 64, sell 1 unit at price 801.340027, investment 0.571047 %, total balance 9190.850158,
# day 65, sell 1 unit at price 806.969971, investment 1.416996 %, total balance 9997.820129,
# day 74: buy 1 unit at price 831.659973, total balance 9166.160156
# day 75, sell 1 unit at price 830.760010, investment -0.108213 %, total balance 9996.920166,
# day 77: buy 1 unit at price 828.640015, total balance 9168.280151
# day 78, sell 1 unit at price 829.280029, investment 0.077237 %, total balance 9997.560180,
# day 81: buy 1 unit at price 830.630005, total balance 9166.930175
# day 82, sell 1 unit at price 829.080017, investment -0.186604 %, total balance 9996.010192,
# day 85: buy 1 unit at price 835.369995, total balance 9160.640197
# day 86, sell 1 unit at price 838.679993, investment 0.396231 %, total balance 9999.320190,
# day 93: buy 1 unit at price 848.400024, total balance 9150.920166
# day 94, sell 1 unit at price 830.460022, investment -2.114569 %, total balance 9981.380188,
# day 95: buy 1 unit at price 829.590027, total balance 9151.790161
# day 96: buy 1 unit at price 817.580017, total balance 8334.210144
# day 97, sell 1 unit at price 814.429993, investment -1.827413 %, total balance 9148.640137,
# day 98: buy 1 unit at price 819.510010, total balance 8329.130127
# day 99, sell 1 unit at price 820.919983, investment 0.408519 %, total balance 9150.050110,
# day 101, sell 1 unit at price 831.500000, investment 1.463068 %, total balance 9981.550110,
# day 104: buy 1 unit at price 834.570007, total balance 9146.980103
# day 106, sell 1 unit at price 827.880005, investment -0.801611 %, total balance 9974.860108,
# day 111: buy 1 unit at price 823.559998, total balance 9151.300110
# day 112, sell 1 unit at price 837.169983, investment 1.652580 %, total balance 9988.470093,
# day 116: buy 1 unit at price 843.190002, total balance 9145.280091
# day 118, sell 1 unit at price 872.299988, investment 3.452364 %, total balance 10017.580079,
# day 120: buy 1 unit at price 874.250000, total balance 9143.330079
# day 121, sell 1 unit at price 905.960022, investment 3.627111 %, total balance 10049.290101,
# day 129: buy 1 unit at price 928.780029, total balance 9120.510072
# day 130: buy 1 unit at price 930.599976, total balance 8189.910096
# day 131, sell 1 unit at price 932.219971, investment 0.370372 %, total balance 9122.130067,
# day 132, sell 1 unit at price 937.080017, investment 0.696329 %, total balance 10059.210084,
# day 140: buy 1 unit at price 969.539978, total balance 9089.670106
# day 144, sell 1 unit at price 966.950012, investment -0.267133 %, total balance 10056.620118,
# day 150: buy 1 unit at price 949.830017, total balance 9106.790101
# day 151: buy 1 unit at price 942.900024, total balance 8163.890077
# day 152, sell 1 unit at price 953.400024, investment 0.375857 %, total balance 9117.290101,
# day 153, sell 1 unit at price 950.760010, investment 0.833597 %, total balance 10068.050111,
# day 158: buy 1 unit at price 959.450012, total balance 9108.600099
# day 160, sell 1 unit at price 965.590027, investment 0.639952 %, total balance 10074.190126,
# day 164: buy 1 unit at price 917.789978, total balance 9156.400148
# day 165: buy 1 unit at price 908.729980, total balance 8247.670168
# day 166, sell 1 unit at price 898.700012, investment -2.079993 %, total balance 9146.370180,
# day 167, sell 1 unit at price 911.710022, investment 0.327935 %, total balance 10058.080202,
# day 172: buy 1 unit at price 943.830017, total balance 9114.250185
# day 173, sell 1 unit at price 947.159973, investment 0.352813 %, total balance 10061.410158,
# day 181: buy 1 unit at price 950.700012, total balance 9110.710146
# day 182, sell 1 unit at price 947.799988, investment -0.305041 %, total balance 10058.510134,
# day 188: buy 1 unit at price 923.650024, total balance 9134.860110
# day 189, sell 1 unit at price 927.960022, investment 0.466627 %, total balance 10062.820132,
# day 197: buy 1 unit at price 926.960022, total balance 9135.860110
# day 199, sell 1 unit at price 910.669983, investment -1.757362 %, total balance 10046.530093,
# day 202: buy 1 unit at price 927.000000, total balance 9119.530093
# day 203: buy 1 unit at price 921.280029, total balance 8198.250064
# day 204: buy 1 unit at price 915.890015, total balance 7282.360049
# day 205, sell 1 unit at price 913.809998, investment -1.422870 %, total balance 8196.170047,
# day 206, sell 1 unit at price 921.289978, investment 0.001080 %, total balance 9117.460025,
# day 208: buy 1 unit at price 939.330017, total balance 8178.130008
# day 210: buy 1 unit at price 928.450012, total balance 7249.679996
# day 211: buy 1 unit at price 927.809998, total balance 6321.869998
# day 213: buy 1 unit at price 926.500000, total balance 5395.369998
# day 214: buy 1 unit at price 929.080017, total balance 4466.289981
# day 215, sell 1 unit at price 932.070007, investment 1.766587 %, total balance 5398.359988,
# day 217, sell 1 unit at price 925.109985, investment -1.513848 %, total balance 6323.469973,
# day 219, sell 1 unit at price 915.000000, investment -1.448652 %, total balance 7238.469973,
# day 220: buy 1 unit at price 921.809998, total balance 6316.659975
# day 221, sell 1 unit at price 931.580017, investment 0.406335 %, total balance 7248.239992,
# day 222, sell 1 unit at price 932.450012, investment 0.642203 %, total balance 8180.690004,
# day 223, sell 1 unit at price 928.530029, investment -0.059197 %, total balance 9109.220033,
# day 224, sell 1 unit at price 920.969971, investment -0.091128 %, total balance 10030.190004,
# day 225: buy 1 unit at price 924.859985, total balance 9105.330019
# day 226, sell 1 unit at price 944.489990, investment 2.122484 %, total balance 10049.820009,
# day 235: buy 1 unit at price 972.599976, total balance 9077.220033
# day 236, sell 1 unit at price 989.250000, investment 1.711909 %, total balance 10066.470033,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
