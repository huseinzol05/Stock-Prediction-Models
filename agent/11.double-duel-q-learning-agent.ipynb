# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        tensor_action, tensor_validation = tf.split(feed,2,1)
        feed_action = tf.layers.dense(tensor_action, output_size)
        feed_validation = tf.layers.dense(tensor_validation, 1)
        self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 1
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-6e3fecb0ab03>:12: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# epoch: 10, total rewards: 190.434938.3, cost: 136.628036, total money: 6246.604921
# epoch: 20, total rewards: 1213.564765.3, cost: 89.261879, total money: 10243.024787
# epoch: 30, total rewards: 514.364985.3, cost: 235.222061, total money: 9543.825007
# epoch: 40, total rewards: 236.960203.3, cost: 137.627090, total money: 8247.760190
# epoch: 50, total rewards: 223.065124.3, cost: 182.194260, total money: 9206.425109
# epoch: 60, total rewards: 85.309992.3, cost: 256.151276, total money: 7122.779962
# epoch: 70, total rewards: 92.824771.3, cost: 251.351761, total money: 10092.824771
# epoch: 80, total rewards: 110.945248.3, cost: 328.887726, total money: 6177.405270
# epoch: 90, total rewards: -44.469968.3, cost: 157.256744, total money: 9955.530032
# epoch: 100, total rewards: 130.805359.3, cost: 363.471100, total money: 10130.805359
# epoch: 110, total rewards: 50.665043.3, cost: 182.910416, total money: 10050.665043
# epoch: 120, total rewards: 248.790102.3, cost: 133.747787, total money: 10248.790102
# epoch: 130, total rewards: 172.670286.3, cost: 252.626511, total money: 10172.670286
# epoch: 140, total rewards: 6.959902.3, cost: 218.629028, total money: 10006.959902
# epoch: 150, total rewards: -5.619938.3, cost: 285.958008, total money: 9994.380062
# epoch: 160, total rewards: -71.744751.3, cost: 203.790009, total money: 9928.255249
# epoch: 170, total rewards: 209.400274.3, cost: 317.535797, total money: 8219.730291
# epoch: 180, total rewards: -65.184941.3, cost: 80.899101, total money: 9934.815059
# epoch: 190, total rewards: -17.025023.3, cost: 283.456909, total money: 9982.974977
# epoch: 200, total rewards: 0.644836.3, cost: 173.382446, total money: 8983.534851

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 768.700012, total balance 9231.299988
# day 2, sell 1 unit at price 762.020020, investment -0.868999 %, total balance 9993.320008,
# day 10: buy 1 unit at price 764.479980, total balance 9228.840028
# day 11, sell 1 unit at price 771.229980, investment 0.882953 %, total balance 10000.070008,
# day 12: buy 1 unit at price 760.539978, total balance 9239.530030
# day 13, sell 1 unit at price 769.200012, investment 1.138669 %, total balance 10008.730042,
# day 18: buy 1 unit at price 770.840027, total balance 9237.890015
# day 19: buy 1 unit at price 758.039978, total balance 8479.850037
# day 20, sell 1 unit at price 747.919983, investment -2.973385 %, total balance 9227.770020,
# day 21, sell 1 unit at price 750.500000, investment -0.994668 %, total balance 9978.270020,
# day 27: buy 1 unit at price 789.270020, total balance 9189.000000
# day 28, sell 1 unit at price 796.099976, investment 0.865351 %, total balance 9985.099976,
# day 45: buy 1 unit at price 806.650024, total balance 9178.449952
# day 47, sell 1 unit at price 807.909973, investment 0.156195 %, total balance 9986.359925,
# day 54: buy 1 unit at price 819.309998, total balance 9167.049927
# day 55, sell 1 unit at price 823.869995, investment 0.556566 %, total balance 9990.919922,
# day 61: buy 1 unit at price 795.695007, total balance 9195.224915
# day 62, sell 1 unit at price 798.530029, investment 0.356295 %, total balance 9993.754944,
# day 70: buy 1 unit at price 820.450012, total balance 9173.304932
# day 71, sell 1 unit at price 818.979980, investment -0.179174 %, total balance 9992.284912,
# day 73: buy 1 unit at price 828.070007, total balance 9164.214905
# day 74, sell 1 unit at price 831.659973, investment 0.433534 %, total balance 9995.874878,
# day 79: buy 1 unit at price 823.210022, total balance 9172.664856
# day 80, sell 1 unit at price 835.239990, investment 1.461349 %, total balance 10007.904846,
# day 88: buy 1 unit at price 845.539978, total balance 9162.364868
# day 89, sell 1 unit at price 845.619995, investment 0.009463 %, total balance 10007.984863,
# day 96: buy 1 unit at price 817.580017, total balance 9190.404846
# day 97, sell 1 unit at price 814.429993, investment -0.385286 %, total balance 10004.834839,
# day 100: buy 1 unit at price 831.409973, total balance 9173.424866
# day 101, sell 1 unit at price 831.500000, investment 0.010828 %, total balance 10004.924866,
# day 103: buy 1 unit at price 838.549988, total balance 9166.374878
# day 105: buy 1 unit at price 831.409973, total balance 8334.964905
# day 106: buy 1 unit at price 827.880005, total balance 7507.084900
# day 108: buy 1 unit at price 824.729980, total balance 6682.354920
# day 109, sell 1 unit at price 823.349976, investment -1.812654 %, total balance 7505.704896,
# day 112: buy 1 unit at price 837.169983, total balance 6668.534913
# day 114, sell 1 unit at price 838.210022, investment 0.817894 %, total balance 7506.744935,
# day 115, sell 1 unit at price 841.650024, investment 1.663287 %, total balance 8348.394959,
# day 116, sell 1 unit at price 843.190002, investment 2.238311 %, total balance 9191.584961,
# day 118, sell 1 unit at price 872.299988, investment 4.196281 %, total balance 10063.884949,
# day 120: buy 1 unit at price 874.250000, total balance 9189.634949
# day 121, sell 1 unit at price 905.960022, investment 3.627111 %, total balance 10095.594971,
# day 122: buy 1 unit at price 912.570007, total balance 9183.024964
# day 123, sell 1 unit at price 916.440002, investment 0.424077 %, total balance 10099.464966,
# day 125: buy 1 unit at price 931.659973, total balance 9167.804993
# day 127: buy 1 unit at price 934.299988, total balance 8233.505005
# day 128, sell 1 unit at price 932.169983, investment 0.054742 %, total balance 9165.674988,
# day 129, sell 1 unit at price 928.780029, investment -0.590812 %, total balance 10094.455017,
# day 137: buy 1 unit at price 941.859985, total balance 9152.595032
# day 138, sell 1 unit at price 948.820007, investment 0.738966 %, total balance 10101.415039,
# day 140: buy 1 unit at price 969.539978, total balance 9131.875061
# day 141: buy 1 unit at price 971.469971, total balance 8160.405090
# day 142, sell 1 unit at price 975.880005, investment 0.653921 %, total balance 9136.285095,
# day 143: buy 1 unit at price 964.859985, total balance 8171.425110
# day 144, sell 1 unit at price 966.950012, investment -0.465270 %, total balance 9138.375122,
# day 145, sell 1 unit at price 975.599976, investment 1.113114 %, total balance 10113.975098,
# day 148: buy 1 unit at price 980.940002, total balance 9133.035096
# day 149, sell 1 unit at price 983.409973, investment 0.251796 %, total balance 10116.445069,
# day 157: buy 1 unit at price 950.630005, total balance 9165.815064
# day 158, sell 1 unit at price 959.450012, investment 0.927807 %, total balance 10125.265076,
# day 160: buy 1 unit at price 965.590027, total balance 9159.675049
# day 161, sell 1 unit at price 952.270020, investment -1.379468 %, total balance 10111.945069,
# day 165: buy 1 unit at price 908.729980, total balance 9203.215089
# day 166, sell 1 unit at price 898.700012, investment -1.103735 %, total balance 10101.915101,
# day 194: buy 1 unit at price 914.390015, total balance 9187.525086
# day 195, sell 1 unit at price 922.669983, investment 0.905518 %, total balance 10110.195069,
# day 196: buy 1 unit at price 922.219971, total balance 9187.975098
# day 197, sell 1 unit at price 926.960022, investment 0.513983 %, total balance 10114.935120,
# day 199: buy 1 unit at price 910.669983, total balance 9204.265137
# day 200, sell 1 unit at price 906.659973, investment -0.440336 %, total balance 10110.925110,
# day 202: buy 1 unit at price 927.000000, total balance 9183.925110
# day 203, sell 1 unit at price 921.280029, investment -0.617041 %, total balance 10105.205139,
# day 213: buy 1 unit at price 926.500000, total balance 9178.705139
# day 215: buy 1 unit at price 932.070007, total balance 8246.635132
# day 216, sell 1 unit at price 935.090027, investment 0.927148 %, total balance 9181.725159,
# day 217: buy 1 unit at price 925.109985, total balance 8256.615174
# day 218, sell 1 unit at price 920.289978, investment -1.263857 %, total balance 9176.905152,
# day 219: buy 1 unit at price 915.000000, total balance 8261.905152
# day 220, sell 1 unit at price 921.809998, investment -0.356713 %, total balance 9183.715150,
# day 221, sell 1 unit at price 931.580017, investment 1.812024 %, total balance 10115.295167,
# day 224: buy 1 unit at price 920.969971, total balance 9194.325196
# day 225, sell 1 unit at price 924.859985, investment 0.422382 %, total balance 10119.185181,
# day 226: buy 1 unit at price 944.489990, total balance 9174.695191
# day 228, sell 1 unit at price 959.109985, investment 1.547925 %, total balance 10133.805176,
# day 230: buy 1 unit at price 957.789978, total balance 9176.015198
# day 231, sell 1 unit at price 951.679993, investment -0.637925 %, total balance 10127.695191,
# day 235: buy 1 unit at price 972.599976, total balance 9155.095215
# day 236, sell 1 unit at price 989.250000, investment 1.711909 %, total balance 10144.345215,
# day 238: buy 1 unit at price 989.679993, total balance 9154.665222
# day 239, sell 1 unit at price 992.000000, investment 0.234420 %, total balance 10146.665222,
# day 240: buy 1 unit at price 992.179993, total balance 9154.485229
# day 241, sell 1 unit at price 992.809998, investment 0.063497 %, total balance 10147.295227,
# day 250: buy 1 unit at price 1016.640015, total balance 9130.655212

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
